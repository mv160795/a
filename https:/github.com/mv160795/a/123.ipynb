# %%
from pyspark.sql import SparkSession
import cv2
import numpy as np
from pyspark.sql.functions import udf
from pyspark.sql.types import BinaryType, StringType, StructType, StructField
import os
import pandas as pd

# Initialize SparkSession
spark = SparkSession.builder \
    .appName("ResizeImages") \
    .getOrCreate()

# Path to the directory containing the original images
input_directory = "/workspaces/a/Fake"

# Path to the directory where resized images will be saved (local file system path)
output_directory = "/workspaces/a"

# Define the resize function
def resize_image(image_path, width=250, height=250):
    # Read the image using OpenCV
    img = cv2.imread(image_path)
    # Resize the image
    resized_img = cv2.resize(img, (width, height))
    # Encode the resized image back into binary format
    retval, buffer = cv2.imencode('.jpg', resized_img)
    resized_image_data = buffer.tobytes()
    return resized_image_data

# Register the UDF (User Defined Function)
resize_image_udf = udf(resize_image, BinaryType())

# List of image file paths in the input directory
image_paths = [os.path.join(input_directory, file) for file in os.listdir(input_directory)]

# Create a schema for the DataFrame
schema = StructType([StructField("image_path", StringType(), nullable=True)])

# Create a DataFrame with the image file paths and schema
image_paths_df = spark.createDataFrame([(path,) for path in image_paths], schema)

# Apply the resize function to the DataFrame
resized_images_df = image_paths_df.withColumn("resized_image", resize_image_udf(image_paths_df["image_path"]))

# Convert the DataFrame to a Pandas DataFrame
pandas_df = resized_images_df.toPandas()

# Save the resized images using OpenCV
for index, row in pandas_df.iterrows():
    image_data = np.frombuffer(row['resized_image'], dtype=np.uint8)
    img = cv2.imdecode(image_data, cv2.IMREAD_COLOR)
    cv2.imwrite(os.path.join(output_directory, f"resized_image_{index}.jpg"), img)

# %%
pandas_df.resized_image[0]
# Out:
# bytearray(b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x02\x01\x01\x01\x01\x01\x02\x01\x01\x01\x02\x02\x02\x02\x02\x04\x03\x02\x02\x02\x02\x05\x04\x04\x03\x04\x06\x05\x06\x06\x06\x05\x06\x06\x06\x07\t\x08\x06\x07\t\x07\x06\x06\x08\x0b\x08\t\n\n\n\n\n\x06\x08\x0b\x0c\x0b\n\x0c\t\n\n\n\xff\xdb\x00C\x01\x02\x02\x02\x02\x02\x02\x05\x03\x03\x05\n\x07\x06\x07\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xff\xc0\x00\x11\x08\x00\xfa\x00\xfa\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xfd\xfc\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8ai\x91A\xc1\xa0\x07QH\x18\x13\x81F\xe1\x9c{P\x02\xd1E\x00\xe7\x9a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa3#8\xa0\x1fZ\x00\x0f#\x15\x1b\xb2"\xfc\xff\x00w\xb59\x98\x8c\x928\xaa\xf3o1\x95\xc0$\x1d\xc1{\xe2\x80%2&\xd1\x97\xc0\xf5\xa5,\x10dt\x1d=\xeb\x0bV\xd74_\x0e\xda\xb6\xb3\xad\xebQ[[M \x1f\xe9\x8e\x15T\x93\x80\x07\xbej\xe4W\rs\x0c2Ep\xb2e|\xc5\x08r\xa5OO\xd0\xd0\x06\x9a\x92\xdf6x\xa7\x03\x91\x9a\x86\x06b\xa3?{\xb8\xa9\x87J\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00(\xa2\x8a\x00iuS\x86<\x9e\x94\xc6\xb9\x8b\xcd0\xee\xf9\x80\xc8\x15\x15\xc1o?\x06u\t\xdcc\xe6\xfc\xea\x8d\xd4\xbb[\xcd\x9aE\x0c\xc71m\x18m\xab\xc9\xc9\xfaP\x05\xf6\xd4`\x11\x17\xde2\xbc\x15\xf7\xaf\x1d\xfd\xb1\xbfm\xff\x00\xd9\xf3\xf6"\xf8aw\xf17\xe3\xa7\x8d\xad\xb4\xd8"\x80\xc9\r\xa0\x99Zy\xdb\x19\xda\xb1\xe7q\xfc\x05|\xd5\xff\x00\x05S\xff\x00\x82\xe2\xfe\xcc\x7f\xf0OO\x0b\xdci6\x1a\xd5\xbe\xbd\xe3;\x88\x9a;=\x1e\xd6`Lr`\x90_#\x07\xa7\xad\x7f2\x7f\xb7o\xfc\x14K\xf6\x87\xfd\xbe~+\\|@\xf8\xdd\xe2\xfb\x9b\x98~\xd4\xef\xa6\xe8O#\x1b{E\'\xe5P\x84\x908\xc7C\xda\x80>\xa8\xff\x00\x82\xad\xff\x00\xc1\xc3\x1f\xb4?\xed\xb7\xe3\xa7\xf0\xcf\xc1o\x10\xdc\xf8\x7f\xc1\xbam\xe2\xbe\x98\xb6\xca\xd0\xcb>\xd6\xca\xb3\x11\xb5\xbb\x0e\r~\xe2\xff\x00\xc1\x00?\xe0\xa0\x16\x7f\xb7\x0f\xecCas\xa9k\ts\xe2_\n"i\xfa\xc4rJ\x0c\xa4\x8e\x8eA\xe4\x8c\x11\xcf\xbd\x7f"\xa9;\t7F\xea2\xcc2\x83\x03\x91\x8e+\xf4\x07\xfe\r\xdf\xff\x00\x82\x91\\~\xc0?\xb6\x96\x9f\xa4\xf8\xae\xfd\x87\x83\xfcw:\xe9z\xe6\xe7\xc2@\xcc\x01I}\x8e\xe4E\xce\x0fZ\x00\xfe\xb7\xed\xe6M\xaas\xc6>\xf7\xbdXS\xb9A"\xb24]OM\xd44\xc8u=2\xed.\xad\xaf!Y\xedY\x0eC\xa9\x19\xdc\x0f\xa7"\xb4\xa0\x97/\xb5\x9b\'g"\x80&\xa2\x9a\xa5\x8b\x1c\x8e;S\xa8\x00\xa2\x8a(\x00\xa2\x8a(\x ...
